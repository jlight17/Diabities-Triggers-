# %% [markdown]
# ### I will be looking at a csv file called "diabetes.csv"
# * I want to see if there is any correlation between any of the keys within the file and having diabetes

# %%
# loading in the library pandas and reading in the csv file diabetes
import pandas as np
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %%
# using the head method to see the top 5 of the data set for now
diabetesDF = pd.read_csv('diabetes.csv')
diabetesDF.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# using .tail() to see the bottom 5 of the dataset
diabetesDF.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
# using sort_values() and Comparing Age and BMI to see if there is a correlation with having diabetes
# looking at just the first 50
diabetesDF.sort_values('Outcome',ascending=False)[['Age','BMI','Outcome']].head(50)
# Out:
#      Age   BMI  Outcome
# 0     50  33.6        1
# 276   29  26.5        1
# 270   38  45.6        1
# 269   28  27.5        1
# 266   25  36.3        1
# 603   54  35.2        1
# 264   35  32.0        1
# 604   36  28.4        1
# 261   27  30.0        1
# 606   22  40.0        1
# 259   51  33.3        1
# 255   21  33.6        1
# 254   44  27.6        1
# 611   36  32.9        1
# 612   40  38.2        1
# 614   50  36.1        1
# 245   49  30.0        1
# 618   50  28.2        1
# 243   33  27.1        1
# 598   38  36.8        1
# 595   22  32.0        1
# 619   24  32.4        1
# 280   28  37.9        1
# 580   21  42.1        1
# 303   28  52.9        1
# 301   25  31.6        1
# 300   30  32.3        1
# 298   46  36.6        1
# 296   29  28.0        1
# 584   52  28.7        1
# 293   24  40.5        1
# 292   31  43.3        1
# 291   25  36.6        1
# 586   41  34.9        1
# 588   52  33.3        1
# 287   29  45.6        1
# 590   45  46.8        1
# ...

# %%
# using sort_values() and Comparing Age and BloodPressure to see if there is a correlation with having diabetes
# looking at just the first 50 
diabetesDF.sort_values('Outcome',ascending=False)[['Age','BloodPressure','Outcome']].head(50)
# Out:
#      Age  BloodPressure  Outcome
# 0     50             72        1
# 276   29             60        1
# 270   38             86        1
# 269   28              0        1
# 266   25              0        1
# 603   54             78        1
# 264   35             62        1
# 604   36              0        1
# 261   27              0        1
# 606   22             78        1
# 259   51             76        1
# 255   21             64        1
# 254   44             62        1
# 611   36             58        1
# 612   40             88        1
# 614   50             74        1
# 245   49             85        1
# 618   50             82        1
# 243   33             50        1
# 598   38             74        1
# 595   22             82        1
# 619   24              0        1
# 280   28             70        1
# 580   21             90        1
# 303   28             98        1
# 301   25             58        1
# 300   30              0        1
# ...

# %%
# printing a heatmap to visually look at the correlations between all the keys within the file 
sb.heatmap(diabetesDF.corr(), annot = True)
plt.show()

# %%
# Finding the Average age of people with Diabetes and without diabetes 
# The average age of someone with Diabetes is 31 and the average age with someone who doesn't have diabetes
# is 37
diabetesDF.groupby(['Outcome']).agg({'Age':'mean'})
# Out:
#                Age
# Outcome
# 0        31.190000
# 1        37.067164

# %%
# On average, the higher your pregnancy count, the more likely you are to have diabetes, from this calculation
diabetesDF.groupby(['Outcome']).agg({'Pregnancies':'mean'})
# Out:
#          Pregnancies
# Outcome
# 0           3.298000
# 1           4.865672

# %%
# On average, the higher your glucose count, the higher risk you have of getting diabetes
diabetesDF.groupby(['Outcome']).agg({'Glucose':'mean'})
# Out:
#             Glucose
# Outcome
# 0        109.980000
# 1        141.257463

# %%
# On average, the higher your Blood Pressure is, the higher risk you have of getting diabetes
diabetesDF.groupby(['Outcome']).agg({'BloodPressure':'mean'})
# Out:
#          BloodPressure
# Outcome
# 0            68.184000
# 1            70.824627

# %%
# On average, the higher your SkinThickness is , the higher risk you have of getting diabetes
diabetesDF.groupby(['Outcome']).agg({'SkinThickness':'mean'})
# Out:
#          SkinThickness
# Outcome
# 0            19.664000
# 1            22.164179

# %%
# On average, the higher your Insulin levels are, the higher risk you have of getting diabetes
diabetesDF.groupby(['Outcome']).agg({'Insulin':'mean'})
# Out:
#             Insulin
# Outcome
# 0         68.792000
# 1        100.335821

# %%
# On average, the higher your Glucose Levels, the higher risk you have of getting diabetes
diabetesDF.groupby(['Outcome']).agg({'BMI':'mean'})
# Out:
#                BMI
# Outcome
# 0        30.304200
# 1        35.142537

# %%
# using the .corr() method to print the correlation for the full table 
# this is the same outcome as the heatmap, but depending on which one is easier to read, I printed both
diabetesDF.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
# creating a new df with sort_values and calling SkinThickness and BMI, since I saw a correlation in the heat map
skinBMIDF = diabetesDF.sort_values('Outcome',ascending=True)[['SkinThickness','BMI']]
skinBMIDF.head(5)
# Out:
#      SkinThickness   BMI
# 383             18  25.1
# 465             13  21.8
# 466             10  27.8
# 467             36  36.8
# 469             41  46.1

# %%
# calculating the correlation between the two
# from this, we can see that there is a correlation between SkinThickness and BMI and the calucated chance 
# of getting diabetes is the same for BMI and SkinThickness at 0.074 and 
skinBMIDF.corr()
# Out:
#                SkinThickness       BMI
# SkinThickness       1.000000  0.392573
# BMI                 0.392573  1.000000

# %%
# creating a new df with sort_values and calling SkinThickness and Insulin
# since I saw a correlation in the heat map
skinInsulinDF = diabetesDF.sort_values('Outcome',ascending=True)[['SkinThickness','Insulin']]
skinInsulinDF.head(5)
# Out:
#      SkinThickness  Insulin
# 383             18       59
# 465             13      105
# 466             10       36
# 467             36      100
# 469             41      140

# %%
skinInsulinDF.corr()
# Out:
#                SkinThickness   Insulin
# SkinThickness       1.000000  0.436783
# Insulin             0.436783  1.000000

# %%
# creating a new df with sort_values and calling Glucose and Insulin
# since I saw a correlation in the heat map
glucoseInsulinDF = diabetesDF.sort_values('Outcome',ascending=True)[['Glucose','Insulin']]
glucoseInsulinDF.head(5)
# Out:
#      Glucose  Insulin
# 383       90       59
# 465      124      105
# 466       74       36
# 467       97      100
# 469      154      140

# %%
glucoseInsulinDF.corr()
# Out:
#           Glucose   Insulin
# Glucose  1.000000  0.331357
# Insulin  0.331357  1.000000

# %%
# creating a new df with sort_values and calling Age and Pregnancies
# since I saw a correlation in the heat map
agePregnanciesDF = diabetesDF.sort_values('Outcome',ascending=True)[['Age','Pregnancies']]
agePregnanciesDF.head(5)
# Out:
#      Age  Pregnancies
# 383   25            1
# 465   21            0
# 466   22            0
# 467   25            0
# 469   27            6

# %%
agePregnanciesDF.corr()
# Out:
#                   Age  Pregnancies
# Age          1.000000     0.544341
# Pregnancies  0.544341     1.000000

# %%
# grouping the whole dataframe by outcome and plotting it in a historgam 
diabetesDF.groupby('Outcome').hist(figsize = (12,8))
# Out:
# Outcome
# 0    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# 1    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# dtype: object

# %%
# printing the correlations in order from greatest to least
corr = diabetesDF.corr()
corrOutcome = corr['Outcome'].sort_values(ascending=False)
print(corrOutcome)
# Out:
# Outcome                     1.000000
# Glucose                     0.466581
# BMI                         0.292695
# Age                         0.238356
# Pregnancies                 0.221898
# DiabetesPedigreeFunction    0.173844
# Insulin                     0.130548
# SkinThickness               0.074752
# BloodPressure               0.065068
# Name: Outcome, dtype: float64

# %%
# mapping the correlation to visually see what key has a higher chance of getting diabetes
for row in corrOutcome:
    corrSort.plot.barh()
